# %%
"""docstring """

import csv
#Import necessary modules


def createfile():
    f = open("marketdata_cleaned.csv")
    #Create a new file
    
def readdata():
    with open("marketdata_sample.csv") as fp:
        reader = csv.reader(fp)
        data = list(reader)
    return data
    #Read the data
    
class Asset:
    def __init__(self, code, name):
        Asset.code = code
        Asset.name = name
        Asset.time = Asset_Time(time)
        
class Asset_Time(Asset):
    #Create an object-class that represents an asset at a certain time
    def __init__(self, time):
        pass
    
    def timeclean(self):
        pass
    
    def volumeclean(self):
        pass
    #Creating methods to clean the data
    
    #. . .
    #Other cleaning methods
    
def cleandata(row):
    #This function cleans data by rows. 
    
def assembly(data):
    cleandata = []
    for i in data:
        cleandata.append(i)
    return cleandata

def main():
    #Main function that completes the work

# %%
readdata()
# Out:
# [['time',
#   'assetCode',
#   'assetName',
#   'universe',
#   'volume',
#   'close',
#   'open',
#   'returnsClosePrevRaw1',
#   'returnsOpenPrevRaw1',
#   'returnsClosePrevMktres1',
#   'returnsOpenPrevMktres1',
#   'returnsClosePrevRaw10',
#   'returnsOpenPrevRaw10',
#   'returnsClosePrevMktres10',
#   'returnsOpenPrevMktres10',
#   'returnsOpenNextMktres10'],
#  ['2007-02-01 22:00:00+00:00',
#   'A.N',
#   'Agilent Technologies Inc',
#   '1.0',
#   '2606900.0',
#   '32.19',
#   '32.17',
#   '0.005937500000000151',
#   '0.005312499999997611',
#   '',
#   '',
#   '-0.0018604651162773544',
#   '0.0006220839813353418',
#   '',
#   '',
#   '0.034672039756225945'],
#  ['2007-02-01 22:00:00+00:00',
#   'AAI.N',
#   'AirTran Holdings Inc',
#   '0.0',
#   '2051600.0',
#   '11.12',
#   '11.08',
#   '0.004516711833784992',
#   '-0.007168458781361964',
#   '',
#   '',
#   '-0.07870753935376973',
#   '-0.08806584362139924',
#   '',
#   '',
#   '0.0278032796083542'],
# ...
